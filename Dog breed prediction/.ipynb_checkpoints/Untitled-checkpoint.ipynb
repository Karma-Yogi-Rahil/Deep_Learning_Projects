# %%
#Library imports
import numpy as np
import streamlit as st
import cv2
from tensorflow.keras.models import load_model


#Loading the Model
model = load_model('dog_breed.h5')

#Name of Classes
CLASS_NAMES = ['Scottish Deerhound','Maltese Dog','Bernese Mountain Dog']

#Setting Title of App
st.title("Dog Breed Prediction")
st.markdown("Upload an image of the dog")

#Uploading the dog image
dog_image = st.file_uploader("Choose an image...", type="png")
submit = st.button('Predict')
#On predict button click
if submit:


    if dog_image is not None:

        # Convert the file to an opencv image.
        file_bytes = np.asarray(bytearray(dog_image.read()), dtype=np.uint8)
        opencv_image = cv2.imdecode(file_bytes, 1)



        # Displaying the image
        st.image(opencv_image, channels="BGR")
        #Resizing the image
        opencv_image = cv2.resize(opencv_image, (224,224))
        #Convert image to 4 Dimension
        opencv_image.shape = (1,224,224,3)
        #Make Prediction
        Y_pred = model.predict(opencv_image)

        st.title(str("The Dog Breed is "+CLASS_NAMES[np.argmax(Y_pred)]))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /var/folders/hx/wlbxzx7n4213spz0xxw82y7h0000gn/T/ipykernel_20933/2136776259.py in <module>
#       7
#       8 #Loading the Model
# ----> 9 model = load_model('dog_breed.h5')
#      10
#      11 #Name of Classes
#
# ~/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     209       filepath = path_to_string(filepath)
#     210       if isinstance(filepath, six.string_types):
# --> 211         loader_impl.parse_saved_model(filepath)
#     212         return saved_model_load.load(filepath, compile, options)
#     213
#
# ~/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages/tensorflow/python/saved_model/loader_impl.py in parse_saved_model(export_dir)
#     109       raise IOError("Cannot parse file %s: %s." % (path_to_pbtxt, str(e)))
#     110   else:
# --> 111     raise IOError("SavedModel file does not exist at: %s/{%s|%s}" %
#     112                   (export_dir,
#     113                    constants.SAVED_MODEL_FILENAME_PBTXT,
#
# OSError: SavedModel file does not exist at: dog_breed.h5/{saved_model.pbtxt|saved_model.pb}

# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Using cached streamlit-1.3.0-py2.py3-none-any.whl (9.2 MB)
# Requirement already satisfied: pillow>=6.2.0 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from streamlit) (8.3.2)
# Requirement already satisfied: numpy in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from streamlit) (1.21.1)
# Requirement already satisfied: blinker in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from streamlit) (1.4)
# Requirement already satisfied: cachetools>=4.0 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from streamlit) (4.2.2)
# Requirement already satisfied: protobuf!=3.11,>=3.6.0 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from streamlit) (3.15.8)
# Collecting gitpython!=3.1.19
#   Using cached GitPython-3.1.24-py3-none-any.whl (180 kB)
# Requirement already satisfied: astor in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from streamlit) (0.8.1)
# Collecting altair>=3.2.0
#   Using cached altair-4.1.0-py3-none-any.whl (727 kB)
# Collecting pyarrow
#   Using cached pyarrow-6.0.1-cp39-cp39-macosx_11_0_arm64.whl (13.8 MB)
# Collecting click<8.0,>=7.0
#   Using cached click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting tzlocal
#   Downloading tzlocal-4.1-py3-none-any.whl (19 kB)
# Collecting base58
#   Using cached base58-2.1.1-py3-none-any.whl (5.6 kB)
# Requirement already satisfied: tornado>=5.0 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from streamlit) (6.1)
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: python-dateutil in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from streamlit) (2.8.2)
# Collecting validators
#   Using cached validators-0.18.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: pandas>=0.21.0 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from streamlit) (1.3.5)
# Collecting pympler>=0.9
#   Using cached Pympler-1.0.1-py3-none-any.whl (164 kB)
# Requirement already satisfied: attrs in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from streamlit) (21.2.0)
# Requirement already satisfied: packaging in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from streamlit) (21.0)
# Collecting pydeck>=0.1.dev5
#   Using cached pydeck-0.7.1-py2.py3-none-any.whl (4.3 MB)
# Requirement already satisfied: requests in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from streamlit) (2.26.0)
# Requirement already satisfied: entrypoints in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from altair>=3.2.0->streamlit) (0.3)
# Collecting toolz
#   Using cached toolz-0.11.2-py3-none-any.whl (55 kB)
# Requirement already satisfied: jinja2 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from altair>=3.2.0->streamlit) (3.0.1)
# Requirement already satisfied: jsonschema in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from altair>=3.2.0->streamlit) (3.2.0)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.9-py3-none-any.whl (63 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from gitpython!=3.1.19->streamlit) (3.10.0.0)
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pytz>=2017.3 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from pandas>=0.21.0->streamlit) (2021.3)
# Requirement already satisfied: six>=1.9 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from protobuf!=3.11,>=3.6.0->streamlit) (1.16.0)
# Requirement already satisfied: ipykernel>=5.1.2 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from pydeck>=0.1.dev5->streamlit) (6.1.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from pydeck>=0.1.dev5->streamlit) (7.6.3)
# Requirement already satisfied: traitlets>=4.3.2 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from pydeck>=0.1.dev5->streamlit) (5.0.5)
# Requirement already satisfied: appnope in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.1.2)
# Requirement already satisfied: ipython<8.0,>=7.23.1 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (7.26.0)
# Requirement already satisfied: jupyter-client<7.0 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (6.1.12)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (1.4.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (3.0.19)
# Requirement already satisfied: pexpect>4.3 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.18.0)
# Requirement already satisfied: pickleshare in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.5)
# Requirement already satisfied: pygments in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (2.9.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (49.6.0.post20210108)
# Requirement already satisfied: backcall in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: decorator in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (5.0.9)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from jedi>=0.16->ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from jinja2->altair>=3.2.0->streamlit) (2.0.1)
# Requirement already satisfied: pyzmq>=13 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from jupyter-client<7.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (22.2.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from jupyter-client<7.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (4.7.1)
# Requirement already satisfied: ipython-genutils in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from jsonschema->altair>=3.2.0->streamlit) (0.17.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from pexpect>4.3->ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.4.3)
# Requirement already satisfied: prometheus-client in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.11.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.10.1)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.8.0)
# Requirement already satisfied: nbconvert in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.1.0)
# Requirement already satisfied: argon2-cffi in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (20.1.0)
# Requirement already satisfied: cffi>=1.0.0 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.14.6)
# Requirement already satisfied: pycparser in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.20)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.4.2)
# Requirement already satisfied: defusedxml in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.4)
# Requirement already satisfied: testpath in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.0)
# Requirement already satisfied: bleach in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (4.0.0)
# Requirement already satisfied: jupyterlab-pygments in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.1.2)
# Requirement already satisfied: async-generator in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.10)
# Requirement already satisfied: nest-asyncio in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.5.1)
# Requirement already satisfied: webencodings in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from packaging->streamlit) (2.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from requests->streamlit) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from requests->streamlit) (2.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from requests->streamlit) (1.26.6)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rahilmehta/miniforge3/envs/homebrew_tensorflow/lib/python3.9/site-packages (from requests->streamlit) (3.1)
# Collecting pytz-deprecation-shim
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Collecting tzdata
#   Downloading tzdata-2021.5-py2.py3-none-any.whl (339 kB)
#      |████████████████████████████████| 339 kB 277 kB/s eta 0:00:01
# Installing collected packages: tzdata, smmap, toolz, pytz-deprecation-shim, gitdb, validators, tzlocal, toml, pympler, pydeck, pyarrow, gitpython, click, base58, altair, streamlit
#   Attempting uninstall: click
#     Found existing installation: click 8.0.1
#     Uninstalling click-8.0.1:
#       Successfully uninstalled click-8.0.1
# Successfully installed altair-4.1.0 base58-2.1.1 click-7.1.2 gitdb-4.0.9 gitpython-3.1.24 pyarrow-6.0.1 pydeck-0.7.1 pympler-1.0.1 pytz-deprecation-shim-0.1.0.post0 smmap-5.0.0 streamlit-1.3.0 toml-0.10.2 toolz-0.11.2 tzdata-2021.5 tzlocal-4.1 validators-0.18.2
